# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx -O retail.xlsx
# Out:
# --2019-09-05 08:04:42--  https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23715344 (23M) [application/x-httpd-php]
# Saving to: ‘retail.xlsx’
#
# retail.xlsx         100%[===================>]  22.62M  31.7MB/s    in 0.7s
#
# 2019-09-05 08:04:43 (31.7 MB/s) - ‘retail.xlsx’ saved [23715344/23715344]

# %%
import pandas as pd
excel_df = pd.read_excel("retail.xlsx")

# %%
print("The number of items: {}".format(len(excel_df["StockCode"].unique())))
print("The number of records: {}".format(len(excel_df.index)))
# Out:
# The number of items: 4070
# The number of records: 541909

# %%
excel_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df = excel_df.loc[:, ["StockCode", "InvoiceDate", "Quantity", "Country"]]

# %%
df = df.set_index("InvoiceDate")

# %%
train_df = df[:"2011-11-30"]
test_df = df["2011-12-01":]

# %%
# Out:
#                     StockCode  Quantity         Country
# InvoiceDate
# 2011-12-01 08:12:00     23245        -8  United Kingdom
# 2011-12-01 08:14:00     84947        -1  United Kingdom
# 2011-12-01 08:14:00     23374        -1  United Kingdom
# 2011-12-01 08:14:00     84945        -2  United Kingdom
# 2011-12-01 08:18:00     23485        -1  United Kingdom
# 2011-12-01 08:18:00     23186        -6  United Kingdom
# 2011-12-01 08:23:00     23461        -4  United Kingdom
# 2011-12-01 08:25:00     37449        -2  United Kingdom
# 2011-12-01 08:26:00     23012        -1  United Kingdom
# 2011-12-01 08:26:00     23568        -1  United Kingdom
# 2011-12-01 08:26:00     23319        -6  United Kingdom
# 2011-12-01 08:27:00     23374        -5  United Kingdom
# 2011-12-01 08:27:00     23456        -2  United Kingdom
# 2011-12-01 08:29:00     23382        -2  United Kingdom
# 2011-12-01 08:29:00     23256        -1  United Kingdom
# 2011-12-01 08:29:00     23203        -1  United Kingdom
# ...
